# %% [markdown]
# # Patient Readmission Prediction - Quick Start
#
# This notebook demonstrates the basic usage of the patient readmission prediction system.
#
# ## ⚠️ DISCLAIMER
# **This is a research demonstration tool only. NOT FOR CLINICAL USE. NOT MEDICAL ADVICE.**

# %%
# Import required libraries
import sys
import os
sys.path.append('src')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from data.utils import (
    DataProcessor,
    generate_synthetic_readmission_data,
    create_patient_level_split,
    compute_class_weights
)
from models.tabular import ModelFactory, get_model_config
from metrics.clinical import ModelEvaluator, create_leaderboard
from utils.core import set_seed, get_device
from utils.explainability import ModelExplainer

# Set random seed for reproducibility
set_seed(42)

print(f"Using device: {get_device()}")
